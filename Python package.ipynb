# %% [markdown]
# ### Python package(Pythonda paketlərin hazırlanması)

# %% [markdown]
# Python dilində modullardan savayı paketlər də mövcuddur.Standart paketlərdən savayı,Üçüncü tərəf python paketləri də mövcuddur.Biz modullara əvvəlki dərslərimizdə giriş etdik.Az-çox modulların hazırlanmasına dair məlumatınız var.Paketlər isə həmin modullardan hazırlanmış python fayllarıdır.Hazırladığımız modulları funksionallığına görə qruplaşdıraraq fərqli qovluqlarda saxlaya bilərik.Paketlər fərqli modul kataloqlarından ibarət olur.

# %% [markdown]
# Python paketləri ilə modulları necə öyrənə bilərik!

# %%
import requests

# %%
requests.__path__
# Out:
# ['C:\\ProgramData\\Anaconda3\\lib\\site-packages\\requests']

# %%
import cv2

# %%
cv2.__path__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-da5eab39ba34> in <module>()
# ----> 1 cv2.__path__
#
# AttributeError: module 'cv2' has no attribute '__path__'

# %% [markdown]
# Və gördüyünüz kimi requests import etdik paket olduğu üçün metod tətbiq olundu.

# %% [markdown]
# Paketlər ümumi halda aşağıdakı rəsm formasındadır.

# %%
from IPython.display import Image
Image("../image/package.png")

# %% [markdown]
# Yuxarıdakı paketimizi hazırlayaq.data adı ilə qovluq hazrlayıram.Daha sonra  <code>__init__.py </code> python faylı hazırladım.

# %% [markdown]
# Və data qovluğu daxilində Generate və Calculate adlı iki qovluq hazırlayıb həmin qovluqlara ayrı ayrılıqda generate.py və calculate.py faylları həmçinin init.py adlı python faylı əlavə edirəm

# %%
import data

# %%
dir(data)
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__path__', '__spec__']

# %%
data.__path__
# Out:
# _NamespacePath(['E:\\Tain\\Python3-AZ\\Package\\data'])

# %% [markdown]
# Və __path__ metodu var olduğundan tətbiq edə bildik.Bu metod python paketlərində mövcud olur.

# %%
data.__package__
# Out:
# 'data'

# %% [markdown]
# Əgər xəta alsaydıq,deməli tək python faylı-modul hazırlamışıq.Və xəta almadıq

# %% [markdown]
# Davam edərək kodları python fayllarına əlavə edək

# %% [markdown]
# <code>
# def factorial_recursive(n):
#     """
#     Returns factorial of a given number using recursion.
#
#     fact(1) -------> 1
#
#     """
#     if n == 1:
#         return 1
#     else:
#         return n * factorial_recursive(n-1)
# </code>

# %% [markdown]
# Yuxarıdakı kodları calculate.py faylına əlavə etdim

# %% [markdown]
# Və data qovluğundan xaricdə package.py faylı açıb paketləri test edək

# %%
from IPython.display import Image
Image("../image/pack.png")

# %% [markdown]
# <code>from data.Calculate import as dc </code> yazaraq paketi import edirik.Ardından funksiyamıza element əlavə edib,ədədin faktorialını rekursiv funksiya vasitəsilə hesablayırıq

# %% [markdown]
# <code>generate.py</code> faylına isə aşağıdakı kodları əlavə edək

# %% [markdown]
# <code>
# def Generasiya(n):
#     generator = (i for i in range(n))
#     generator = iter(generator)
#     while True:
#         try:
#             print (next(generator))
#         except StopIteration:
#             break
#
#
#
# </code>

# %%
from IPython.display import Image
Image("../image/pack1.png")

# %% [markdown]
# Və <code> __init__.py </code> fayllarına <code>__all__ = ['generate'] </code>    <code>__all__ = ['calculate'] </code> əlavə edib yaddaşa veririk

# %% [markdown]
# <code>
# import data.Calculate as dc
# print(dc.__all__)
#
#
#
#
# C:\ProgramData\Anaconda3\python.exe E:/Tain/Python3-AZ/Package/package.py
# ['calculate']
#
# Process finished with exit code 0
#
# </code>

# %% [markdown]
# yuxarıdakı kodları yazdıqda modul adını ekranda görə bilirik
