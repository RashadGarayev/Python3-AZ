# %% [markdown]
# # Modules (Modullar)

# %% [markdown]
# Modullar Python proqramlaşdırma dilində sinifləri,funksiyaları və verilənləri ayrı-ayrı fayllarda yerləşdirməyə imkan verir.Biz,python interaktiv moddan çıxdıqda,yazdığımız funksiyalar-ifadələr öz funksionallığını itirir.Modullardan istifadə etməklə iri həcmli proqramları hissələrə bölməklə istifadə etmək mümkündür.

# %% [markdown]
# Modulları hazırlamaq üçün python faylları hazırlamağımız şərtdir.Modullar təkrar kod yazmaq,kodları kopalamaq və s kimi zəhmətlərdən bizim yardımçımız olur.Asta-asta giriş etdikcə modulların necə faydalı olduğunun şahidi olacaqsınız.Və siz modullara dəfələrlə rast gələcəksiniz.Məsələn,siz triqonometriya,loqarifma diskriminant kimi məsələləri öyrənmək üçün riyaziyyat kitabına ehtiyacınız olacaq.Burda kitab bir modul daxilindəki ayrı ayrı dərslər isə funksiya və sinifləridir.

# %% [markdown]
# İstifadəçi tərəfndən hazırlanan modullardan savayı Python dilinin standart kitabxanasına aid olan modullar da vardır.os,sys,math və s.(Ətraflı növbəti dərslərdə hər birini öyrənəcəyik)

# %% [markdown]
# ## *Modullar python faylı olub,sonluğu py və ya pyw ilə bitir. (modul.py)

# %% [markdown]
# Yazdığınız modul faylın adını qeyd edərkən mütləq diqqətli olun,standart kitabxanada olan modul adlarından istifadə etməyin

# %% [markdown]
# ### *Modulu çağırmaq üçün import ifadəsindən istifadə edirik

# %% [markdown]
# #### import modul_adı

# %% [markdown]
# #### modul_adı.atribut

# %% [markdown]
# Modul_adı çağırılan python faylı və ya modul adı,atribut isə modul daxilində yazılmış funksiya,siniflər və ya digər komponentlərdir

# %% [markdown]
# İlk öncə Python dili standart kitabxanalarına aid olan modullara nəzər yetirək

# %%
import sys  #sys modulunu proqrama daxil edirik(import edirik)

# %%
sys.path
# Out:
# ['',
#  'C:\\ProgramData\\Anaconda3\\python36.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\garay\\.ipython']

# %% [markdown]
# ## Proqrama modullar daxil olunanda,interpretator onları aşağıdakı ardıcıllıqla axtarır.
#
# ### 1.Cari kataloq
# ### 2.PYTHONPATH mühitində olan kataloqlar
# ### 3.Platformadan asılı təyin edilən kataloqlar

# %% [markdown]
# Kataloqların yeri əməliyyat sistemindən asılı olaraq fərqli ola bilər.Mən hal-hazırda Ubuntu 19.10 Linux distribyutoru istifadə etdiyimdən yuxarıdakı qaydada,pythonpath kataloqu sıralandı

# %% [markdown]
# Modulda tərtib olunan atributları əldə etmək üçün isə dir() - ifadəsindən istifadə olunur.

# %%
import sys
# dir(sys) sətir boyu məlumatların kifayət qədər çox olduğundan kodu çalışdırmadım. siz dir(sys) yazaraq çalışdırın

# %%
import os # os modulu

# %%
# dir(os)

# %%
cd E:\Tain\Python3-AZ
# Out:
# E:\Tain\Python3-AZ

# %%
# ls

# %% [markdown]
# Və os modulunun olduğu qovluğu açırıq

# %%
#Susmaya görə əvvəlki qovluğa qayıdırıq

# %%
cd E:\Tain\Python3-AZ
# Out:
# E:\Tain\Python3-AZ

# %%
from IPython.display import Image
Image("image/screen.png")

# %% [markdown]
# Daxilində funksiyaların olduğunu görürük.Və biz import os yazaraq modulu import edirik daha sonra daxilindəki işimizə yararlı funksiya və ya sinifləri çağırırıq.

# %%
import os
os.name
# Out:
# 'nt'

# %% [markdown]
# Yuxarıdakı nümunədə os modulunu çağırırıq daha sonra os modulu daxilində funksiya və sinifləri istifadə edirik

# %% [markdown]
# Şəxsi modulumuzu hazırlasaq,siz bu bəhsi tamamilə daha yaxşı mənimsəyəcəksiniz.

# %%
ls
# Out:
#  Volume in drive E is TOSHIBA EXT
#  Volume Serial Number is 5297-426A
#
#  Directory of E:\Tain\Python3-AZ
#
# 03/16/2020  06:22 AM    <DIR>          .
# 03/16/2020  06:22 AM    <DIR>          ..
# 02/07/2020  10:25 AM    <DIR>          .ipynb_checkpoints
# 03/16/2020  03:52 AM    <DIR>          __pycache__
# 12/13/2019  01:00 PM                 2 CONTRIBUTING.md
# 03/16/2020  06:21 AM               485 function.py
# 03/16/2020  03:47 AM            89,896 Functions.ipynb
# 01/19/2020  01:29 PM         3,972,047 Giris-DataTypes.ipynb
# 02/07/2020  12:46 PM    <DIR>          image
# 03/16/2020  06:22 AM         1,285,181 Modules(Modullar).ipynb
# 01/29/2020  12:29 PM           109,139 Operators.ipynb
# 12/20/2019  10:24 AM             8,524 README.md
#                7 File(s)      5,465,274 bytes
#                5 Dir(s)  447,503,470,592 bytes free

# %% [markdown]
# Olduğumuz qovluqda python faylı açırıq

# %%
echo  > function.py

# %%
! dir
# Out:
#  Volume in drive E is TOSHIBA EXT
#  Volume Serial Number is 5297-426A
#
#  Directory of E:\Tain\Python3-AZ
#
# 03/16/2020  06:26 AM    <DIR>          .
# 03/16/2020  06:26 AM    <DIR>          ..
# 02/07/2020  10:25 AM    <DIR>          .ipynb_checkpoints
# 12/13/2019  01:00 PM                 2 CONTRIBUTING.md
# 03/16/2020  06:21 AM               485 function - Copy.py
# 03/16/2020  06:26 AM                13 function.py
# 03/16/2020  03:47 AM            89,896 Functions.ipynb
# 01/19/2020  01:29 PM         3,972,047 Giris-DataTypes.ipynb
# 02/07/2020  12:46 PM    <DIR>          image
# 03/16/2020  06:26 AM         1,286,722 Modules(Modullar).ipynb
# 01/29/2020  12:29 PM           109,139 Operators.ipynb
# 12/20/2019  10:24 AM             8,524 README.md
# 03/16/2020  03:52 AM    <DIR>          __pycache__
#                8 File(s)      5,466,828 bytes
#                5 Dir(s)  447,401,660,416 bytes free

# %% [markdown]
# Hazırladığımız function.py faylına əlavələrimizi edək

# %% [raw]
# #function.py faylı
# """
# def toplama(x,y):
#     result = x+y
#     return result
#
# """

# %% [markdown]
# Yazdığımız funksiya digər faylda olduğu üçün artıq həmin fayl bizim üçün bir modul sayılır.Modulu çağırmağın ilk metoduna nəzər salaq

# %%
import function

# %% [markdown]
# Modulu import ifadəsi ilə çağırdıq və aşağı sətrə xətasız keçid etdik.İlk əvvəl qeyd etdiyim kimi pythonda modulu çağırarkən ilk olaraq Cari kataloq a nəzər yetirir daha sonra pythonpath kataloqu yoxlanılır.Faylımız cari kataloqda olduğu üçün pythonpath bölməsinə keçid etmədi

# %%
dir(function)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'toplama']

# %% [markdown]
# dir funksiyası vasitəsilə modul daxilində nələrin olduğunu əyani göstərək

# %% [markdown]
# Yuxarıda qeyd olunanları irəliləyən bəhslərdə öyrənəcəyik.Hal-hazırda sonda addition ifadəsini görürük-bu bizim yazdığımız funksiyadır.Əgər fayl daxilində bir neçə funksiya və ya sinif qeyd etsəydik hər biri ekrana çap olunacaqdı

# %%
#funksiyadan istifadə edək
import function
function.toplama()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-dcbd7f3ef360> in <module>()
#       1 #funksiyadan istifadə edək
#       2 import function
# ----> 3 function.toplama()
#
# TypeError: toplama() missing 2 required positional arguments: 'x' and 'y'

# %% [markdown]
# Və xəta aldıq.Bu xətaları funksiyalar bəhsində öyrənmişdik.Çünki funksiya 3 arqument aldığı halda biz boş ötürdük

# %%
#funksiyadan istifadə edək
import function
function.toplama(2,3) #2+3 = 5
# Out:
# 5

# %% [markdown]
# Bəli,moduldan rahatlıqla istifadə etdik.

# %% [markdown]
# Faylımıza digər funkiyalar da əlavə edək

# %% [markdown]
# Hazırladığımız python faylını pycharm mətn editorunda açıram

# %%
from IPython.display import Image
Image("image/moduls.png")

# %% [markdown]
# python faylına bir neçə riyazi əməlləri yerinə yetirən funksiyalar əlavə etdim.Burada function.py fayl adı yəni function modul adıdır.

# %% [markdown]
# Və modulu istənilən fayldan çağıraraq istifadə edə bilərik

# %% [markdown]
# Növbəti test.py faylını eyni qovluqda hazırlayırıq.və function modulumuzu həmin python faylından çağıraq

# %%
from IPython.display import Image
Image("image/moduls1.png")

# %% [markdown]
# Yuxarıda gördüyünüz kimi modul daxilində hasil funksiyasından istifadə etdik.İstifadədən öncə isə modul daxilində digər elementləri də ekrana çap etdik.
